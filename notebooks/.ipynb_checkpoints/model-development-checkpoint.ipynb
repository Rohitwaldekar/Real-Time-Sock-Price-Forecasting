# %% [markdown]
# # Import libraries

# %%
import pathlib
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from datetime import datetime
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Read data from file

# %%
path = pathlib.Path('D:\Data Science\Real-Time-Data-Analysis\data\\raw\data-v1.csv')

df = pd.read_csv(path,index_col='index',parse_dates=True)

# %% [markdown]
# # Looking into data

# %%
df.head()
# Out:
#                           Open       High        Low      Close  Adj Close  \
# index
# 2022-08-01 09:30:00  19.360001  19.525000  19.350000  19.455000  19.455000
# 2022-08-01 10:30:00  19.459999  19.620001  19.450001  19.620001  19.620001
# 2022-08-01 11:30:00  19.610001  19.620001  19.504999  19.525000  19.525000
# 2022-08-01 12:30:00  19.525000  19.540001  19.480000  19.495001  19.495001
# 2022-08-01 13:30:00  19.500000  19.540001  19.480000  19.530001  19.530001
#
#                       Volume
# index
# 2022-08-01 09:30:00  1543009
# 2022-08-01 10:30:00   781953
# 2022-08-01 11:30:00   613057
# 2022-08-01 12:30:00   734559
# 2022-08-01 13:30:00  1195479

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  455.000000  455.000000  455.000000  455.000000  455.000000
# mean    18.446047   18.503086   18.395451   18.449305   18.449305
# std      1.113284    1.102984    1.122986    1.113832    1.113832
# min     16.424999   16.545000   16.389999   16.424999   16.424999
# 25%     17.514999   17.600000   17.450000   17.525001   17.525001
# 50%     18.365000   18.420000   18.320000   18.365000   18.365000
# 75%     19.390000   19.435000   19.347500   19.392500   19.392500
# max     20.485001   20.600000   20.440001   20.485001   20.485001
#
#              Volume
# count  4.550000e+02
# mean   1.160302e+06
# std    9.572886e+05
# min    1.706300e+05
# 25%    5.370620e+05
# 50%    8.426680e+05
# 75%    1.486831e+06
# max    8.628966e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 455 entries, 2022-08-01 09:30:00 to 2022-10-31 15:30:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       455 non-null    float64
#  1   High       455 non-null    float64
#  2   Low        455 non-null    float64
#  3   Close      455 non-null    float64
#  4   Adj Close  455 non-null    float64
#  5   Volume     455 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 24.9 KB

# %%
plt.plot(df.index, df["Close"])
plt.title("Infosys stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.show()

# %% [markdown]
# # Find p, d, and q values for ARIMA model

# %%
''' p is order of Autoregration
    d is number of differencing requiredd to make time series stationary
    q is order Moving aaverages'''
# Out:
# ' p is order of Autoregration\n    d is number of differencing requiredd to make time series stationary\n    q is order Moving aaverages'

# %% [markdown]
# ## Stationarity

# %%
''' Substract current value from previous value. We need to do diffenting peration multiple times to make series stationary.
    Select minimun value for ARIMA model.'''
# Out:
# ' Substract current value from previous value. We need to do diffenting peration multiple times to make series stationary.\n    Select minimun value for ARIMA model.'

# %%
from statsmodels.tsa.stattools import adfuller

# %%
dftest = adfuller(df['Close'],autolag='AIC')
print('1. ADF :',dftest[0])
print('2. P-value :',dftest[1])
print('3. No of lags :',dftest[2])
print('4. No of observations used for ADF Regression and Crirical value calculation :',dftest[3])
print('5. Critical values :')
for k, v in dftest[4].items():
    print('\t',k,' :',v)
# Out:
# 1. ADF : -1.2103346134224993
# 2. P-value : 0.6691342969517478
# 3. No of lags : 0
# 4. No of observations used for ADF Regression and Crirical value calculation : 454
# 5. Critical values :
# 	 1%  : -3.444836032925901
# 	 5%  : -2.8679272692747415
# 	 10%  : -2.5701721745036776

# %%
from pmdarima import auto_arima
import warnings
warnings.filterwarnings('ignore')

# %%
stepswise_fit = auto_arima(df['Close'], trace=True, suppress_warnings=True)
stepswise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-726.133, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-732.561, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-731.094, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-731.112, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-734.462, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-729.963, Time=0.28 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.133 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  455
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 368.231
# Date:                Fri, 11 Nov 2022   AIC                           -734.462
# Time:                        22:25:49   BIC                           -730.344
# Sample:                             0   HQIC                          -732.840
#                                 - 455
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0116      0.000     32.173      0.000       0.011       0.012
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):               980.25
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# plt.figure()
# lag_plot(df['Open'], lag=3)
# plt.title('Infosys Stock - Autocorrelation plot with lag = 3')
# plt.show()

# %%
train_data, test_data = df[0:int(len(df)*0.7)], df[int(len(df)*0.7):]

training_data = train_data['Close'].values
test_data = test_data['Close'].values

history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)

for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
    
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 0.013842255520304565

# %%
model = ARIMA(history, order=(0,1,0))
model_fit = model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  455
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 368.231
# Date:                Fri, 11 Nov 2022   AIC                           -734.462
# Time:                        22:26:26   BIC                           -730.344
# Sample:                             0   HQIC                          -732.840
#                                 - 455
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0116      0.000     32.173      0.000       0.011       0.012
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):               980.25
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start= len(train_data)
end = len(train_data)+len(test_data)-1
pred = model_fit.predict(start=start, end= end, typ='levels')

MSE_error = mean_squared_error(test_data, pred)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 0.013691540128936117

# %%
print(end)
# Out:
# 454

# %%
test_set_range = df[int(len(df)*0.7):]
plt.plot(test_set_range.index, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range.index, test_data, color='red', label='Actual Price')
plt.title('Infosys Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
# plt.xticks(np.arange(881,1259,50), df.Date[881:1259:50])
plt.legend()
plt.show()

# %%
test_set_range = df[int(len(df)*0.7):]
plt.plot(test_set_range.index, pred, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range.index, test_data, color='red', label='Actual Price')
plt.title('Infosys Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
# plt.xticks(np.arange(881,1259,50), df.Date[881:1259:50])
plt.legend()
plt.show()

# %%
df.tail()
# Out:
#                           Open    High        Low      Close  Adj Close  \
# index
# 2022-10-31 11:30:00  18.754999  18.760  18.684999  18.719999  18.719999
# 2022-10-31 12:30:00  18.725000  18.760  18.680000  18.760000  18.760000
# 2022-10-31 13:30:00  18.750000  18.785  18.735001  18.764999  18.764999
# 2022-10-31 14:30:00  18.760000  18.830  18.719999  18.740000  18.740000
# 2022-10-31 15:30:00  18.740000  18.770  18.709999  18.735001  18.735001
#
#                       Volume
# index
# 2022-10-31 11:30:00   695776
# 2022-10-31 12:30:00   481401
# 2022-10-31 13:30:00  1341238
# 2022-10-31 14:30:00  1686403
# 2022-10-31 15:30:00  1805751

# %%
history = [x for x in df['Close'].values]

model2 = ARIMA(history, order=(0,1,0))
model_fit2 = model2.fit()
model_fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  455
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 368.231
# Date:                Fri, 11 Nov 2022   AIC                           -734.462
# Time:                        22:26:43   BIC                           -730.344
# Sample:                             0   HQIC                          -732.840
#                                 - 455
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0116      0.000     32.173      0.000       0.011       0.012
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.53   Jarque-Bera (JB):               980.25
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
future_index = pd.date_range(start='2022-11-01 09:30:00', end='2022-11-10 15:30:00', freq='1H')

# %%
future_index[:10]
# Out:
# DatetimeIndex(['2022-11-01 09:30:00', '2022-11-01 10:30:00',
#                '2022-11-01 11:30:00', '2022-11-01 12:30:00',
#                '2022-11-01 13:30:00', '2022-11-01 14:30:00',
#                '2022-11-01 15:30:00', '2022-11-01 16:30:00',
#                '2022-11-01 17:30:00', '2022-11-01 18:30:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
start= len(train_data)
end = len(train_data)+len(future_index)-1
pred = model_fit2.predict(start=start, end= end, typ='levels')

# %%
print(len(future_index))
print(len(pred))
# Out:
# 223
# 223

# %%
plt.plot(future_index, pred, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.title('Infosys Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
# plt.xticks(np.arange(881,1259,50), df.Date[881:1259:50])
plt.legend()
plt.show()
